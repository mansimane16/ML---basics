# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv("test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
x=df.math
y=df.cs

# %%
def gradient_descent(x,y):
    m_curr=b_curr=0
    n=len(x)
    rate=0.0002
    cost_previous=0
    plt.scatter(x,y,color="green",marker="+")
    for i in range(10):
        y_predicted = m_curr * x + b_curr
        cost = (1/n)*sum([value**2 for value in (y-y_predicted)])
        #print(m_curr,b_curr,i,cost)  
        plt.plot(x,y_predicted,color="red")
        md=-(2/n)*np.sum(x*(y-y_predicted))
        bd=-(2/n)*np.sum(y-y_predicted)
        m_curr=m_curr - rate * md
        b_curr = b_curr - rate *bd
        
        if math.isclose(cost, cost_previous, rel_tol=1e-20):
            break
        cost_previous = cost
        print ("m {}, b {}, cost {}, iteration {}".format(m_curr,b_curr,cost, i))
    return m_curr, b_curr
     

if __name__ == "__main__":
    df = pd.read_csv("test_scores.csv")
    x = np.array(df.math)
    y = np.array(df.cs)

    m, b = gradient_descent(x,y)
    print("Using gradient descent function: Coef {} Intercept {}".format(m, b))
# Out:
# m 1.9783600000000003, b 0.027960000000000002, cost 5199.1, iteration 0
# m 0.2097504127999994, b 0.0030470367999999894, cost 4161.482445460163, iteration 1
# m 1.7908456142986249, b 0.02540128695526401, cost 3332.223731926927, iteration 2
# m 0.3773816366753042, b 0.005499731626422644, cost 2669.4843523162017, iteration 3
# m 1.6409848166378902, b 0.023373894401807944, cost 2139.8263837751474, iteration 4
# m 0.5113514173939646, b 0.007477430543482794, cost 1716.5264071567622, iteration 5
# m 1.5212165764726313, b 0.02177112969849867, cost 1378.227200780454, iteration 6
# m 0.618419142678513, b 0.009075514323270565, cost 1107.8601808918434, iteration 7
# m 1.425498156359763, b 0.020507724625171392, cost 891.784221517846, iteration 8
# m 0.7039868810749309, b 0.010370210797388452, cost 719.0974036421321, iteration 9
# Using gradient descent function: Coef 0.7039868810749309 Intercept 0.010370210797388452

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[["math"]],df.cs)
# Out:
# LinearRegression()

# %%
reg.predict([[88]])
# Out:
# C:\Users\Mansi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([91.47600824])

# %%
reg.coef_
# Out:
# array([1.01773624])

# %%
reg.intercept_
# Out:
# 1.9152193111569176
